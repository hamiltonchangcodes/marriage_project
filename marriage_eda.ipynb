# %%
import pandas as pd
import matplotlib as plt

# %%
import thinkstats2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-a254293471cf> in <module>
# ----> 1 import thinkstats2
#
# ModuleNotFoundError: No module named 'thinkstats2'

# %%
df = pd.read_csv('data/1996.csv')

# %%
df.head(15)
# Out:
#    GROOM_FIRST_NAME GROOM_MIDDLE_NAME GROOM_SURNAME BRIDE_FIRST_NAME  \
# 0           MICHAEL           RUDOLPH         ROETT         MARGARET
# 1            RONALD               NaN        BOWMAN          MARILYN
# 2            PIERRE               NaN        JOUTHE       ANTOINETTE
# 3             DAVID            EDWARD       SECREST         CAROLINA
# 4            ROBERT            ALONZO         ALLEN          LINETTA
# 5            TYRONE           ANTHONY          MATA           DORICE
# 6            DELROY               NaN         GRANT            KAREN
# 7             AHMED               NaN       SHEHATA           GLORIA
# 8             JEMAL               NaN   BRAITHWAITE           JANNIA
# 9              LEON             GEROL       HEYWOOD            WENDY
# 10           ELOZER             YONAH     STEINMETZ            MALKA
# 11             RAUL            CARLOS          STIO            DIANA
# 12           GERARD                P.         SMART            KARLA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74095 entries, 0 to 74094
# Data columns (total 11 columns):
# GROOM_FIRST_NAME      74095 non-null object
# GROOM_MIDDLE_NAME     46194 non-null object
# GROOM_SURNAME         74094 non-null object
# BRIDE_FIRST_NAME      74092 non-null object
# BRIDE_MIDDLE_NAME     44016 non-null object
# BRIDE_SURNAME         74093 non-null object
# DATE_OF_MARRIAGE      74095 non-null object
# LICENSE_CITY          74095 non-null object
# LICENSE_BOROUGH_ID    74095 non-null int64
# LICENSE_YEAR          74095 non-null int64
# LICENSE_SEQ           74095 non-null int64
# dtypes: int64(3), object(8)
# memory usage: 6.2+ MB

# %%
df.LICENSE_CITY.value_counts()
# Out:
# Manhattan        30124
# Queens           17365
# Brooklyn         12535
# Bronx            10678
# Staten Island     3393
# Name: LICENSE_CITY, dtype: int64

# %%
rf = pd.read_csv('data/1997.csv')

# %%
rf.LICENSE_CITY.value_counts()
# Out:
# Manhattan        30310
# Queens           16884
# Brooklyn         12401
# Bronx            10959
# Staten Island     4638
# Name: LICENSE_CITY, dtype: int64

# %%
dfnew = pd.concat([df, rf])

# %%
dfnew.head(20)
# Out:
#    GROOM_FIRST_NAME GROOM_MIDDLE_NAME   GROOM_SURNAME BRIDE_FIRST_NAME  \
# 0           MICHAEL           RUDOLPH           ROETT         MARGARET
# 1            RONALD               NaN          BOWMAN          MARILYN
# 2            PIERRE               NaN          JOUTHE       ANTOINETTE
# 3             DAVID            EDWARD         SECREST         CAROLINA
# 4            ROBERT            ALONZO           ALLEN          LINETTA
# 5            TYRONE           ANTHONY            MATA           DORICE
# 6            DELROY               NaN           GRANT            KAREN
# 7             AHMED               NaN         SHEHATA           GLORIA
# 8             JEMAL               NaN     BRAITHWAITE           JANNIA
# 9              LEON             GEROL         HEYWOOD            WENDY
# 10           ELOZER             YONAH       STEINMETZ            MALKA
# 11             RAUL            CARLOS            STIO            DIANA
# ...

# %%
dfnew.LICENSE_YEAR.value_counts()
# Out:
# 1997    75192
# 1996    74095
# Name: LICENSE_YEAR, dtype: int64

# %%
today = pd.read_csv('data/2014-2017.csv')

# %%
today.head(20)
# Out:
#    GROOM_FIRST_NAME GROOM_MIDDLE_NAME GROOM_SURNAME BRIDE_FIRST_NAME  \
# 0          MICHELLE                 E        VENITO          TIMOTHY
# 1              ANNE                 V       DIFABIO             ADAM
# 2             ERIKA               NaN      ESPINOZA          RODRIGO
# 3            SAMUEL             TYLER   MC CANDLESS             LISA
# 4            SYLVIE               NaN         QUIRK        ALEXANDER
# 5           ROBERT                  A     FRIEDRICH             SEAN
# 6             CEBIN               NaN          TANG          DANPING
# 7           ALBERT                  H           LUK             LIZA
# 8             MEGAN                 B       BRENNAN           JOSEPH
# 9           EVELINA               NaN         KATZI           MARIUS
# 10           HILARY              JANE        FOSTER          BRADLEY
# 11         XIN YUAN               NaN            WU          ZHI MEI
# 12            PETER                 Z           CAO            SUSAN
# ...

# %%
today.LICENSE_CITY.value_counts()
# Out:
# Manhattan        140131
# Queens            59668
# Brooklyn          48865
# Bronx             45039
# Staten Island     13333
# Name: LICENSE_CITY, dtype: int64

# %%
df = pd.read_fwf('data/2015_2017_FemRespData.dat', colspecs = colspecs, headers = None, nrows=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2d25d6aa90b9> in <module>
# ----> 1 df = pd.read_fwf('data/2015_2017_FemRespData.dat', colspecs = colspecs, headers = None, nrows=None)
#
# NameError: name 'colspecs' is not defined

# %%
df.head()
# Out:
#   70623516531616165 1  4000006 50  1 115       11           16255 5211131 2 135  \
# 0  70624140514040405 1  2000004 31  5 16111994  1...
# 1  70625515521515155 1  4000006 50  1 105       1...
# 2  70627135533535355 1  4220001 11115 16111998  1...
# 3  70628128522828285 1  5331001 11111 15112006  1...
# 4  7063051751181817121  3000006 50  15115       1...
#
#    125  055  05  0    0                000 Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 0  135  055  05  0  0                000 5        NaN        NaN         NaN
# 1  125  055  05  0    0                000        NaN        NaN         NaN
# 2  135  315  31  2  2201420142009200900001    2115 55     215 55         NaN
# 3  105  315  31  3  3201220122007200600005        NaN        NaN         NaN
# 4  145  055  05  0  0                000 5        NaN        NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 247  Unnamed: 248  Unnamed: 249  Unnamed: 250  \
# 0         NaN  ...           NaN           8.0           NaN           8.0
# ...

# %%
cd code
# Out:
# [Errno 2] No such file or directory: 'code'
# /Users/hamiltonchang/Documents/Projects/marriage_project

# %%
df = pd.read_stata('data/2015_2017_FemPregSetup.dct')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-c883a350762a> in <module>
# ----> 1 df = pd.read_stata('data/2015_2017_FemPregSetup.dct')
#
# /anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# /anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ...

# %%
df = pd.read_fwf('data/2015_2017_FemPregSetup.dct')

# %%
df.head(20)
# Out:
#                                          dictionary {  \
# 0                                                 NaN
# 1   **********************************************...
# 2   * NATIONAL SURVEY OF FAMILY GROWTH (NSFG), 201...
# 3                   * STATA Pregnancy Data Dictionary
# 4                                                   *
# 5          * Warning: Edit this file at your own risk
# 6                                                   *
# 7   **********************************************...
# 8                                                 NaN
# 9                                           _lines(1)
# 10                                                NaN
# 11                                           _line(1)
# 12                                                NaN
# 13  _column(1)       long                         ...
# 14  _column(6)       byte                         ...
# 15  _column(8)       byte                         ...
# ...

# %%
df.tail(5)
# Out:
#                                           dictionary {  \
# 257  _column(365)        int                       ...
# 258  _column(369)       str2                       ...
# 259  _column(371)       str1                       ...
# 260  _column(372)       str4                       ...
# 261                                                  }
#
#                                             Unnamed: 1 Unnamed: 2
# 257  "Century month of January Five Years Prior to ...      eck A
# 258                    "Quarter when case was sampled"        NaN
# 259  "Regular- or double-sample portion of the quar...        NaN
# 260            "Calendar year when interview occurred"        NaN
# 261                                                NaN        NaN
